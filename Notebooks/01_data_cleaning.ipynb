# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 961.5 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.4 MB 1.2 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/12.4 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.4 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/12.4 MB 1.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/12.4 MB 1.1 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.6/12.4 MB 1.1 MB/s eta 0:00:11
# ...

# %%
import numpy as np

# %%
import matlib
